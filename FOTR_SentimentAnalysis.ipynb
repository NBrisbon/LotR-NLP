# %%
import pandas as pd
import nltk
from nltk import word_tokenize
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.text import Text
from nltk.corpus import brown
import requests
from bs4 import BeautifulSoup
nltk.download('popular')
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular

# %%
r = requests.get('https://archive.org/stream/TheLordOfTheRing1TheFellowshipOfTheRing/The+Lord+Of+The+Ring+1-The+Fellowship+Of+The+Ring_djvu.txt')

# Setting the correct text encoding of the HTML page
r.encoding = 'utf-8'

# Extracting the HTML from the request object
html = r.text

# Printing the first 2000 characters in html
print(html[:2000])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <!-- __ _ _ _ __| |_ (_)__ _____
#     / _` | '_/ _| ' \| |\ V / -_)
#     \__,_|_| \__|_||_|_| \_/\___| -->
#   <head>
#     <title>Full text of &quot;The Lord Of The Rings series&quot;</title>
#
#           <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#
#         <meta name="google-site-verification" content="Q2YSouphkkgHkFNP7FgAkc4TmBs1Gmag3uGNndb53B8" />
#     <meta name="google-site-verification" content="bpjKvUvsX0lxfmjg19TLblckWkDpnptZEYsBntApxUk" />
#
#     <script>
# /* @licstart  The following is the entire license notice for the
#  * JavaScript code in this page.
#  *
#  * This program is free software: you can redistribute it and/or modify
#  * it under the terms of the GNU Affero General Public License as published by
#  * the Free Software Foundation, either version 3 of the License, or
#  * (at your option) any later version.
#  *
#  * This program is distributed in the hope that it will be useful,
#  * but WITHOUT ANY WARRANTY; without even the implied warranty of
#  * MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
#  * GNU Affero General Public License for more details.
#  *
#  * You should have received a copy of the GNU Affero General Public License
#  * along with this program.  If not, see <http://www.gnu.org/licenses/>.
#  *
#  * @licend  The above is the entire license notice
#  * for the JavaScript code in this page.
#  */
# </script>
#         <script>window.archive_setup=[]</script>
#     <meta charset="UTF-8">
#     <script src="//archive.org/includes/jquery-1.10.2.min.js?v1.10.2" type="text/javascript"></script>
#             <script src="//archive.org/includes/analytics.js?v=748273f8" type="text/javascript"></script>
#     <script>
#       'use strict';
#       if ('archive_analytics' in window) {
#                   archive_analytics.service = "ao_2";
#
#         archive_analytics.send_pageview_on_load({"mediaType":"texts"});
#
#         archive_analytics.process_url_events(window.location);
#       }
#     </script>
#         <script s

# %%
# Creating a BeautifulSoup object from the HTML
soup = BeautifulSoup(html, 'html.parser')

# Getting the text out of the soup
text = soup.get_text()

# Fixing mistakes in text
text = text.replace('N®menor', 'Numenor')
text = text.replace('H®rin', 'Hurin')
text = text.replace('T®rin', 'Turin')
text = text.replace('D®nedain', 'Dunedain')
text = text.replace('ores', 'orcs')
text = text.replace('Khazad-dym', 'Khazad-dum')
text = text.replace('And®ril', 'Anduril') 
text = text.replace('Lothlurien', 'Lothlorien')
text = text.replace('Lurien', 'Lorien')
text = text.replace('Forcst', 'Forest')


# Entire Book
FOTR = text[16363:1021945]

  ## PROLONGUE ##

# Concerning Hobbits
p1 = FOTR[0:19430] 

# Concerning Pipe-weed
p2 = FOTR[19436:22791]

# Of the Ordering of the Shire
p3 = FOTR[22797:27493]

# Of the Finding of the Ring
p4 = FOTR[27499:36075]

# NOTE ON THE SHIRE RECORDS
p5 = FOTR[36081:41360]

  ## BOOK 1 ##

# A Long Expected Party
b1_1 = FOTR[41381:96384]

# The Shadow of the Past
b1_2 = FOTR[96390:156092]

# Three is Company
b1_3 = FOTR[156098:207998]

# A Short Cut to Mushrooms
b1_4 = FOTR[208004:239136]

# A Conspiracy Unmasked
b1_5 = FOTR[239142:266920]

# The Old Forest
b1_6 = FOTR[266925:302280]

# In the House of Tom Bombadil
b1_7 = FOTR[302286:332328]

# Fog on the Barrow-Downs 
b1_8 = FOTR[332334:368502]

# At the Sign of The Prancing Pony 
b1_9 = FOTR[368508:402448]

# Strider
b1_10 = FOTR[402453:433350]

# A Knife in the Dark
b1_11 = FOTR[433356:484433]

# Flight to the Ford
b1_12 = FOTR[484438:531603]

  ## BOOK 2 ##
    
# Many Meetings
b2_1 = FOTR[531624:580340]

# The Council of Elrond
b2_2 = FOTR[580347:666210]

# The Ring Goes South
b2_3 = FOTR[666215:723395]

# A Journey in the Dark
b2_4 = FOTR[723400:785328]

# The Bridge of Khazad-dum
b2_5 = FOTR[785334:814630]

# Lothlorien
b2_6 = FOTR[814636:865064]

# The Mirror of Galadriel
b2_7 = FOTR[865069:901276]

# Farewell to Lorien
b2_8 = FOTR[901282:934245]

# The Great River
b2_9 = FOTR[934251:972952]

#The Breaking of the Fellowship 
b2_10 = FOTR[972958:]


#print(b1_6)

# %%
# Find specific spots in the text
FOTR.find("The Breaking of the Fellowship")
# Out:
# 972970

# %%
texts = [p1,p2,p3,p4,p5,b1_1,b1_2,b1_3,b1_4,b1_5,b1_6,b1_7,b1_8,b1_9,b1_10,b1_11,b1_12,b2_1,b2_2,b2_3,
         b2_4,b2_5,b2_6,b2_7,b2_8,b2_9,b2_10]

data = pd.DataFrame(data=[text for text in texts], columns=['Text'])

display(data.head(27))
# Out:
#                                                  Text
# 0   1. Concerning Hobbits \n\n\n\nThis book is lar...
# 1   2. Concerning Pipe-weed \n\n\n\nThere is anoth...
# 2   3. Of the Ordering of the Shire \n\n\n\nThe Sh...
# 3   4. Of the Finding of the Ring \n\n\n\nAs is to...
# 4   NOTE ON THE SHIRE RECORDS \n\n\n\nAt the end o...
# 5   Chapter 1 . A Long-expected Party \n\nWhen Mr....
# 6   Chapter 2 . The Shadow of the Past \n\n\n\nThe...
# 7   Chapter 3 . Three is Company \n\n\n\n'You ough...
# 8   Chapter 4 . A Short Cut to Mushrooms \n\n\n\nI...
# 9   Chapter 5 . A Conspiracy Unmasked \n\n\n\n'Now...
# 10  Chapter 6. The Old Forest \n\n\n\nFrodo woke s...
# 11  Chapter 7 . In the House of Tom Bombadil \n\n\...
# 12  Chapter 8 . Fog on the Barrow-Downs \n\n\n\nTh...
# 13  Chapter 9 . At the Sign of \n\n\n\nThe Prancin...
# 14  Chapter 10. Strider \n\n\n\nFrodo, Pippin, and...
# 15  Chapter 11. A Knife in the Dark \n\n\n\nAs the...
# 16  Chapter 12 . Flight to the Ford \n\n\n\nWhen F...
# 17  Chapter 1 . Many Meetings \n\nFrodo woke and f...
# 18  Chapter 2 . The Council of Elrond \n\n\n\nNext...
# 19  Chapter 3 . The Ring Goes South \n\n\n\nLater ...
# 20  Chapter 4 . A Journey in the Dark \n\n\n\nIt w...
# 21  Chapter 5 . The Bridge of Khazad-dum \n\n\n\nT...
# 22  Chapter 6 . Lothlorien \n\n\n\n'Alas! I Fear w...
# 23  Chapter 7 . The Mirror of Galadriel \n\n\n\nTh...
# 24  Chapter 8 . Farewell to Lorien \n\n\n\nThat ni...
# 25  Chapter 9 . The Great River \n\n\n\nFrodo was ...
# 26  Chapter 10. The Breaking of the Fellowship \n\...

# %%
chapters = ['Concerning Hobbits', 'Concerning Pipe-weed', 'Of the Ordering of the Shire', 'Of the Finding of the Ring',
           'NOTE ON THE SHIRE RECORDS', 'A Long-expected Party', 'The Shadow of the Past', 'Three is Company',
           'A Short Cut to Mushrooms', 'A Conspiracy Unmasked', 'The Old Forest', 'In the House of Tom Bombadil',
           'Fog on the Barrow-Downs', 'At the Sign of The Prancing Pony', 'Strider', 'A Knife in the Dark', 
           'Flight to the Ford', 'Many Meetings', 'The Council of Elrond', 'The Ring Goes South', 'A Journey in the Dark',
           'The Bridge of Khazad-dum', 'Lothlorien', 'The Mirror of Galadriel', 'Farewell to Lorien', 'The Great River',
           'The Breaking of the Fellowship']

book = ['Prologue', 'Prologue', 'Prologue', 'Prologue','Prologue', 'Book I', 'Book I', 'Book I','Book I', 
        'Book I', 'Book I', 'Book I','Book I', 'Book I', 'Book I', 'Book I', 'Book I', 'Book II', 'Book II', 
        'Book II', 'Book II','Book II', 'Book II', 'Book II', 'Book II', 'Book II','Book II']

data1 = pd.DataFrame(chapters, columns=['Chapters'])

data1_1 = pd.merge(data, data1, left_index=True, right_index=True)

data1_2 = pd.DataFrame(book, columns=['Book'])

data2 = pd.merge(data1_1, data1_2, left_index=True, right_index=True)


display(data2.head(27))
# Out:
#                                                  Text                          Chapters      Book
# 0   1. Concerning Hobbits \n\n\n\nThis book is lar...                Concerning Hobbits  Prologue
# 1   2. Concerning Pipe-weed \n\n\n\nThere is anoth...              Concerning Pipe-weed  Prologue
# 2   3. Of the Ordering of the Shire \n\n\n\nThe Sh...      Of the Ordering of the Shire  Prologue
# 3   4. Of the Finding of the Ring \n\n\n\nAs is to...        Of the Finding of the Ring  Prologue
# 4   NOTE ON THE SHIRE RECORDS \n\n\n\nAt the end o...         NOTE ON THE SHIRE RECORDS  Prologue
# 5   Chapter 1 . A Long-expected Party \n\nWhen Mr....             A Long-expected Party    Book I
# 6   Chapter 2 . The Shadow of the Past \n\n\n\nThe...            The Shadow of the Past    Book I
# 7   Chapter 3 . Three is Company \n\n\n\n'You ough...                  Three is Company    Book I
# 8   Chapter 4 . A Short Cut to Mushrooms \n\n\n\nI...          A Short Cut to Mushrooms    Book I
# 9   Chapter 5 . A Conspiracy Unmasked \n\n\n\n'Now...             A Conspiracy Unmasked    Book I
# 10  Chapter 6. The Old Forest \n\n\n\nFrodo woke s...                    The Old Forest    Book I
# 11  Chapter 7 . In the House of Tom Bombadil \n\n\...      In the House of Tom Bombadil    Book I
# 12  Chapter 8 . Fog on the Barrow-Downs \n\n\n\nTh...           Fog on the Barrow-Downs    Book I
# 13  Chapter 9 . At the Sign of \n\n\n\nThe Prancin...  At the Sign of The Prancing Pony    Book I
# 14  Chapter 10. Strider \n\n\n\nFrodo, Pippin, and...                           Strider    Book I
# 15  Chapter 11. A Knife in the Dark \n\n\n\nAs the...               A Knife in the Dark    Book I
# 16  Chapter 12 . Flight to the Ford \n\n\n\nWhen F...                Flight to the Ford    Book I
# 17  Chapter 1 . Many Meetings \n\nFrodo woke and f...                     Many Meetings   Book II
# 18  Chapter 2 . The Council of Elrond \n\n\n\nNext...             The Council of Elrond   Book II
# 19  Chapter 3 . The Ring Goes South \n\n\n\nLater ...               The Ring Goes South   Book II
# 20  Chapter 4 . A Journey in the Dark \n\n\n\nIt w...             A Journey in the Dark   Book II
# 21  Chapter 5 . The Bridge of Khazad-dum \n\n\n\nT...          The Bridge of Khazad-dum   Book II
# 22  Chapter 6 . Lothlorien \n\n\n\n'Alas! I Fear w...                        Lothlorien   Book II
# 23  Chapter 7 . The Mirror of Galadriel \n\n\n\nTh...           The Mirror of Galadriel   Book II
# 24  Chapter 8 . Farewell to Lorien \n\n\n\nThat ni...                Farewell to Lorien   Book II
# 25  Chapter 9 . The Great River \n\n\n\nFrodo was ...                   The Great River   Book II
# 26  Chapter 10. The Breaking of the Fellowship \n\...    The Breaking of the Fellowship   Book II

# %%
data2['Volume']='FOTR'
data2 = data2[['Volume', 'Book', 'Chapters', 'Text']]
data2
# Out:
#    Volume      Book                          Chapters                                               Text
# 0    FOTR  Prologue                Concerning Hobbits  1. Concerning Hobbits \n\n\n\nThis book is lar...
# 1    FOTR  Prologue              Concerning Pipe-weed  2. Concerning Pipe-weed \n\n\n\nThere is anoth...
# 2    FOTR  Prologue      Of the Ordering of the Shire  3. Of the Ordering of the Shire \n\n\n\nThe Sh...
# 3    FOTR  Prologue        Of the Finding of the Ring  4. Of the Finding of the Ring \n\n\n\nAs is to...
# 4    FOTR  Prologue         NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS \n\n\n\nAt the end o...
# 5    FOTR    Book I             A Long-expected Party  Chapter 1 . A Long-expected Party \n\nWhen Mr....
# 6    FOTR    Book I            The Shadow of the Past  Chapter 2 . The Shadow of the Past \n\n\n\nThe...
# 7    FOTR    Book I                  Three is Company  Chapter 3 . Three is Company \n\n\n\n'You ough...
# 8    FOTR    Book I          A Short Cut to Mushrooms  Chapter 4 . A Short Cut to Mushrooms \n\n\n\nI...
# 9    FOTR    Book I             A Conspiracy Unmasked  Chapter 5 . A Conspiracy Unmasked \n\n\n\n'Now...
# 10   FOTR    Book I                    The Old Forest  Chapter 6. The Old Forest \n\n\n\nFrodo woke s...
# 11   FOTR    Book I      In the House of Tom Bombadil  Chapter 7 . In the House of Tom Bombadil \n\n\...
# 12   FOTR    Book I           Fog on the Barrow-Downs  Chapter 8 . Fog on the Barrow-Downs \n\n\n\nTh...
# 13   FOTR    Book I  At the Sign of The Prancing Pony  Chapter 9 . At the Sign of \n\n\n\nThe Prancin...
# 14   FOTR    Book I                           Strider  Chapter 10. Strider \n\n\n\nFrodo, Pippin, and...
# 15   FOTR    Book I               A Knife in the Dark  Chapter 11. A Knife in the Dark \n\n\n\nAs the...
# 16   FOTR    Book I                Flight to the Ford  Chapter 12 . Flight to the Ford \n\n\n\nWhen F...
# 17   FOTR   Book II                     Many Meetings  Chapter 1 . Many Meetings \n\nFrodo woke and f...
# 18   FOTR   Book II             The Council of Elrond  Chapter 2 . The Council of Elrond \n\n\n\nNext...
# 19   FOTR   Book II               The Ring Goes South  Chapter 3 . The Ring Goes South \n\n\n\nLater ...
# 20   FOTR   Book II             A Journey in the Dark  Chapter 4 . A Journey in the Dark \n\n\n\nIt w...
# 21   FOTR   Book II          The Bridge of Khazad-dum  Chapter 5 . The Bridge of Khazad-dum \n\n\n\nT...
# 22   FOTR   Book II                        Lothlorien  Chapter 6 . Lothlorien \n\n\n\n'Alas! I Fear w...
# 23   FOTR   Book II           The Mirror of Galadriel  Chapter 7 . The Mirror of Galadriel \n\n\n\nTh...
# 24   FOTR   Book II                Farewell to Lorien  Chapter 8 . Farewell to Lorien \n\n\n\nThat ni...
# 25   FOTR   Book II                   The Great River  Chapter 9 . The Great River \n\n\n\nFrodo was ...
# 26   FOTR   Book II    The Breaking of the Fellowship  Chapter 10. The Breaking of the Fellowship \n\...

# %%
import pandas as pd
from nltk import tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 

chapters = [p1,p2,p3,p4,p5,b1_1,b1_2,b1_3,b1_4,b1_5,b1_6,b1_7,b1_8,b1_9,b1_10,b1_11,b1_12,b2_1,b2_2,b2_3,
         b2_4,b2_5,b2_6,b2_7,b2_8,b2_9,b2_10]

analyzer = SentimentIntensityAnalyzer()

sentiments_list = list()

for chapter in chapters:
    sentence_list = tokenize.sent_tokenize(chapter)
    sentiments = {'compound': 0.0, 'neg': 0.0, 'neu': 0.0, 'pos': 0.0}
        
    for sentence in sentence_list:
        vs = analyzer.polarity_scores(sentence)
        sentiments['compound'] += vs['compound']
        sentiments['neg'] += vs['neg']
        sentiments['neu'] += vs['neu']
        sentiments['pos'] += vs['pos']
            
    sentiments['compound'] = sentiments['compound'] / len(sentence_list)
    sentiments['neg'] = sentiments['neg'] / len(sentence_list)
    sentiments['neu'] = sentiments['neu'] / len(sentence_list)
    sentiments['pos'] = sentiments['pos'] / len(sentence_list)
    
    sentiments_list.append(sentiments)  # add this line

data3 = pd.DataFrame(sentiments_list)  # add this line
data3
# Out:
#     compound       neg       neu       pos
# 0   0.133970  0.043674  0.880891  0.075450
# 1   0.239865  0.014870  0.903565  0.081609
# 2   0.042571  0.041147  0.903382  0.055471
# 3   0.075828  0.075471  0.841000  0.083485
# 4   0.115635  0.025703  0.914108  0.060162
# 5   0.092960  0.050563  0.854325  0.095113
# 6   0.023151  0.080364  0.835787  0.083856
# 7   0.062997  0.039382  0.887917  0.072693
# 8   0.011641  0.054406  0.882502  0.063086
# 9   0.083426  0.049687  0.853551  0.096768
# 10  0.050078  0.059573  0.859174  0.081251
# 11  0.109893  0.051551  0.848711  0.099737
# 12  0.063105  0.056751  0.864729  0.078517
# 13  0.063927  0.044007  0.889855  0.066140
# 14  0.031716  0.064495  0.854428  0.081069
# 15 -0.017724  0.078997  0.860830  0.060170
# 16 -0.039676  0.077316  0.866580  0.056111
# 17  0.092482  0.047418  0.856683  0.095900
# 18  0.007270  0.074671  0.853501  0.071823
# 19  0.000085  0.064984  0.863647  0.068535
# 20 -0.018587  0.068742  0.871763  0.059500
# 21 -0.073328  0.097166  0.859562  0.043271
# 22  0.050481  0.052154  0.882938  0.064901
# 23  0.045263  0.061203  0.860048  0.078742
# 24  0.091091  0.050251  0.866813  0.082930
# 25 -0.020113  0.065061  0.890092  0.044852
# 26 -0.025731  0.099378  0.834948  0.065674

# %%
FOTR_sentiments = pd.merge(data2, data3, left_index=True, right_index=True)

FOTR_sentiments=FOTR_sentiments.rename(columns={"compound": "Compound", "neg": "Negative", "neu": "Neutral", "pos": "Positive"})

FOTR_sentiments.to_csv(r'C:\Users\Nick\Desktop\GitProjects\NLP_projects\FOTR\FOTR_sentiments.csv')

FOTR_sentiments
# Out:
#    Volume      Book                          Chapters                                               Text  Compound  Negative   Neutral  Positive
# 0    FOTR  Prologue                Concerning Hobbits  1. Concerning Hobbits \n\n\n\nThis book is lar...  0.133970  0.043674  0.880891  0.075450
# 1    FOTR  Prologue              Concerning Pipe-weed  2. Concerning Pipe-weed \n\n\n\nThere is anoth...  0.239865  0.014870  0.903565  0.081609
# 2    FOTR  Prologue      Of the Ordering of the Shire  3. Of the Ordering of the Shire \n\n\n\nThe Sh...  0.042571  0.041147  0.903382  0.055471
# 3    FOTR  Prologue        Of the Finding of the Ring  4. Of the Finding of the Ring \n\n\n\nAs is to...  0.075828  0.075471  0.841000  0.083485
# 4    FOTR  Prologue         NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS \n\n\n\nAt the end o...  0.115635  0.025703  0.914108  0.060162
# 5    FOTR    Book I             A Long-expected Party  Chapter 1 . A Long-expected Party \n\nWhen Mr....  0.092960  0.050563  0.854325  0.095113
# 6    FOTR    Book I            The Shadow of the Past  Chapter 2 . The Shadow of the Past \n\n\n\nThe...  0.023151  0.080364  0.835787  0.083856
# 7    FOTR    Book I                  Three is Company  Chapter 3 . Three is Company \n\n\n\n'You ough...  0.062997  0.039382  0.887917  0.072693
# 8    FOTR    Book I          A Short Cut to Mushrooms  Chapter 4 . A Short Cut to Mushrooms \n\n\n\nI...  0.011641  0.054406  0.882502  0.063086
# 9    FOTR    Book I             A Conspiracy Unmasked  Chapter 5 . A Conspiracy Unmasked \n\n\n\n'Now...  0.083426  0.049687  0.853551  0.096768
# 10   FOTR    Book I                    The Old Forest  Chapter 6. The Old Forest \n\n\n\nFrodo woke s...  0.050078  0.059573  0.859174  0.081251
# 11   FOTR    Book I      In the House of Tom Bombadil  Chapter 7 . In the House of Tom Bombadil \n\n\...  0.109893  0.051551  0.848711  0.099737
# 12   FOTR    Book I           Fog on the Barrow-Downs  Chapter 8 . Fog on the Barrow-Downs \n\n\n\nTh...  0.063105  0.056751  0.864729  0.078517
# 13   FOTR    Book I  At the Sign of The Prancing Pony  Chapter 9 . At the Sign of \n\n\n\nThe Prancin...  0.063927  0.044007  0.889855  0.066140
# 14   FOTR    Book I                           Strider  Chapter 10. Strider \n\n\n\nFrodo, Pippin, and...  0.031716  0.064495  0.854428  0.081069
# 15   FOTR    Book I               A Knife in the Dark  Chapter 11. A Knife in the Dark \n\n\n\nAs the... -0.017724  0.078997  0.860830  0.060170
# 16   FOTR    Book I                Flight to the Ford  Chapter 12 . Flight to the Ford \n\n\n\nWhen F... -0.039676  0.077316  0.866580  0.056111
# 17   FOTR   Book II                     Many Meetings  Chapter 1 . Many Meetings \n\nFrodo woke and f...  0.092482  0.047418  0.856683  0.095900
# 18   FOTR   Book II             The Council of Elrond  Chapter 2 . The Council of Elrond \n\n\n\nNext...  0.007270  0.074671  0.853501  0.071823
# 19   FOTR   Book II               The Ring Goes South  Chapter 3 . The Ring Goes South \n\n\n\nLater ...  0.000085  0.064984  0.863647  0.068535
# 20   FOTR   Book II             A Journey in the Dark  Chapter 4 . A Journey in the Dark \n\n\n\nIt w... -0.018587  0.068742  0.871763  0.059500
# 21   FOTR   Book II          The Bridge of Khazad-dum  Chapter 5 . The Bridge of Khazad-dum \n\n\n\nT... -0.073328  0.097166  0.859562  0.043271
# 22   FOTR   Book II                        Lothlorien  Chapter 6 . Lothlorien \n\n\n\n'Alas! I Fear w...  0.050481  0.052154  0.882938  0.064901
# 23   FOTR   Book II           The Mirror of Galadriel  Chapter 7 . The Mirror of Galadriel \n\n\n\nTh...  0.045263  0.061203  0.860048  0.078742
# 24   FOTR   Book II                Farewell to Lorien  Chapter 8 . Farewell to Lorien \n\n\n\nThat ni...  0.091091  0.050251  0.866813  0.082930
# 25   FOTR   Book II                   The Great River  Chapter 9 . The Great River \n\n\n\nFrodo was ... -0.020113  0.065061  0.890092  0.044852
# 26   FOTR   Book II    The Breaking of the Fellowship  Chapter 10. The Breaking of the Fellowship \n\... -0.025731  0.099378  0.834948  0.065674

# %%
from textblob import TextBlob

blob_book = TextBlob(FOTR)
blob_p1 = TextBlob(p1)
blob_p2 = TextBlob(p2)
blob_p3 = TextBlob(p3)
blob_p4 = TextBlob(p4)
blob_p5 = TextBlob(p5)
blob_b1_1 = TextBlob(b1_1)
blob_b1_2 = TextBlob(b1_2)
blob_b1_3 = TextBlob(b1_3)
blob_b1_4 = TextBlob(b1_4)
blob_b1_5 = TextBlob(b1_5)
blob_b1_6 = TextBlob(b1_6)
blob_b1_7 = TextBlob(b1_7)
blob_b1_8 = TextBlob(b1_8)
blob_b1_9 = TextBlob(b1_9)
blob_b1_10 = TextBlob(b1_10)
blob_b1_11 = TextBlob(b1_11)
blob_b1_12 = TextBlob(b1_12)
blob_b2_1 = TextBlob(b2_1)
blob_b2_2 = TextBlob(b2_2)
blob_b2_3 = TextBlob(b2_3)
blob_b2_4 = TextBlob(b2_4)
blob_b2_5 = TextBlob(b2_5)
blob_b2_6 = TextBlob(b2_6)
blob_b2_7 = TextBlob(b2_7)
blob_b2_8 = TextBlob(b2_8)
blob_b2_9 = TextBlob(b2_9)
blob_b2_10 = TextBlob(b2_10)

# %%
blobs = [blob_p1, blob_p2, blob_p3, blob_p4, blob_p5, blob_b1_1, blob_b1_2, blob_b1_3, blob_b1_4, blob_b1_5,
        blob_b1_6, blob_b1_7, blob_b1_8, blob_b1_9, blob_b1_10, blob_b1_11, blob_b1_12, blob_b2_1, blob_b2_2,
        blob_b2_3, blob_b2_4, blob_b2_5, blob_b2_6, blob_b2_7, blob_b2_8, blob_b2_9, blob_b2_10]

polarity_list = list()
subjectivity_list = list()

for blob in blobs:
    sentence_list1 = blob.sentences
    polarity = (0)
    subjectivity = (0)
        
    for sentence in sentence_list1:
        pl=sentence.sentiment.polarity
        polarity += pl
        sb=sentence.sentiment.subjectivity
        subjectivity += sb
            
    polarity = polarity / len(sentence_list1)
    subjectivity = subjectivity / len(sentence_list1)

    polarity_list.append(polarity)  
    subjectivity_list.append(subjectivity)

data4 = pd.DataFrame(polarity_list)  
data5 = pd.DataFrame(subjectivity_list)  
data6 = pd.merge(data4, data5, left_index=True, right_index=True)
data6=data6.rename(columns={'0_x': "Polarity", '0_y': 'Subjectivity'})

data6
# Out:
#     Polarity  Subjectivity
# 0   0.123098      0.453589
# 1   0.191711      0.472525
# 2   0.097907      0.441715
# 3   0.041690      0.336673
# 4   0.220372      0.394603
# 5   0.063388      0.297571
# 6   0.046675      0.299241
# 7   0.056428      0.285911
# 8   0.048184      0.262968
# 9   0.046885      0.278871
# 10  0.011858      0.283457
# 11  0.078520      0.314967
# 12  0.012824      0.315016
# 13  0.055907      0.274922
# 14  0.018458      0.252212
# 15  0.012372      0.298401
# 16  0.007771      0.303397
# 17  0.073006      0.287620
# 18  0.040775      0.304679
# 19  0.037318      0.313236
# 20  0.010430      0.304156
# 21  0.014297      0.247021
# 22  0.055373      0.290735
# 23  0.051823      0.331532
# 24  0.062147      0.321413
# 25  0.018566      0.306630
# 26  0.003442      0.237485

# %%
FOTR_sentiments = pd.merge(FOTR_sentiments, data6, left_index=True, right_index=True)

FOTR_sentiments.to_csv(r'C:\Users\Nick\Desktop\GitProjects\NLP_projects\FOTR\FOTR_sentiments.csv')

FOTR_sentiments
# Out:
#    Volume      Book                          Chapters                                               Text  Compound  Negative   Neutral  Positive  Polarity  Subjectivity
# 0    FOTR  Prologue                Concerning Hobbits  1. Concerning Hobbits \n\n\n\nThis book is lar...  0.133970  0.043674  0.880891  0.075450  0.123098      0.453589
# 1    FOTR  Prologue              Concerning Pipe-weed  2. Concerning Pipe-weed \n\n\n\nThere is anoth...  0.239865  0.014870  0.903565  0.081609  0.191711      0.472525
# 2    FOTR  Prologue      Of the Ordering of the Shire  3. Of the Ordering of the Shire \n\n\n\nThe Sh...  0.042571  0.041147  0.903382  0.055471  0.097907      0.441715
# 3    FOTR  Prologue        Of the Finding of the Ring  4. Of the Finding of the Ring \n\n\n\nAs is to...  0.075828  0.075471  0.841000  0.083485  0.041690      0.336673
# 4    FOTR  Prologue         NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS \n\n\n\nAt the end o...  0.115635  0.025703  0.914108  0.060162  0.220372      0.394603
# 5    FOTR    Book I             A Long-expected Party  Chapter 1 . A Long-expected Party \n\nWhen Mr....  0.092960  0.050563  0.854325  0.095113  0.063388      0.297571
# 6    FOTR    Book I            The Shadow of the Past  Chapter 2 . The Shadow of the Past \n\n\n\nThe...  0.023151  0.080364  0.835787  0.083856  0.046675      0.299241
# 7    FOTR    Book I                  Three is Company  Chapter 3 . Three is Company \n\n\n\n'You ough...  0.062997  0.039382  0.887917  0.072693  0.056428      0.285911
# 8    FOTR    Book I          A Short Cut to Mushrooms  Chapter 4 . A Short Cut to Mushrooms \n\n\n\nI...  0.011641  0.054406  0.882502  0.063086  0.048184      0.262968
# 9    FOTR    Book I             A Conspiracy Unmasked  Chapter 5 . A Conspiracy Unmasked \n\n\n\n'Now...  0.083426  0.049687  0.853551  0.096768  0.046885      0.278871
# 10   FOTR    Book I                    The Old Forest  Chapter 6. The Old Forest \n\n\n\nFrodo woke s...  0.050078  0.059573  0.859174  0.081251  0.011858      0.283457
# 11   FOTR    Book I      In the House of Tom Bombadil  Chapter 7 . In the House of Tom Bombadil \n\n\...  0.109893  0.051551  0.848711  0.099737  0.078520      0.314967
# 12   FOTR    Book I           Fog on the Barrow-Downs  Chapter 8 . Fog on the Barrow-Downs \n\n\n\nTh...  0.063105  0.056751  0.864729  0.078517  0.012824      0.315016
# 13   FOTR    Book I  At the Sign of The Prancing Pony  Chapter 9 . At the Sign of \n\n\n\nThe Prancin...  0.063927  0.044007  0.889855  0.066140  0.055907      0.274922
# 14   FOTR    Book I                           Strider  Chapter 10. Strider \n\n\n\nFrodo, Pippin, and...  0.031716  0.064495  0.854428  0.081069  0.018458      0.252212
# 15   FOTR    Book I               A Knife in the Dark  Chapter 11. A Knife in the Dark \n\n\n\nAs the... -0.017724  0.078997  0.860830  0.060170  0.012372      0.298401
# 16   FOTR    Book I                Flight to the Ford  Chapter 12 . Flight to the Ford \n\n\n\nWhen F... -0.039676  0.077316  0.866580  0.056111  0.007771      0.303397
# 17   FOTR   Book II                     Many Meetings  Chapter 1 . Many Meetings \n\nFrodo woke and f...  0.092482  0.047418  0.856683  0.095900  0.073006      0.287620
# 18   FOTR   Book II             The Council of Elrond  Chapter 2 . The Council of Elrond \n\n\n\nNext...  0.007270  0.074671  0.853501  0.071823  0.040775      0.304679
# 19   FOTR   Book II               The Ring Goes South  Chapter 3 . The Ring Goes South \n\n\n\nLater ...  0.000085  0.064984  0.863647  0.068535  0.037318      0.313236
# 20   FOTR   Book II             A Journey in the Dark  Chapter 4 . A Journey in the Dark \n\n\n\nIt w... -0.018587  0.068742  0.871763  0.059500  0.010430      0.304156
# 21   FOTR   Book II          The Bridge of Khazad-dum  Chapter 5 . The Bridge of Khazad-dum \n\n\n\nT... -0.073328  0.097166  0.859562  0.043271  0.014297      0.247021
# 22   FOTR   Book II                        Lothlorien  Chapter 6 . Lothlorien \n\n\n\n'Alas! I Fear w...  0.050481  0.052154  0.882938  0.064901  0.055373      0.290735
# 23   FOTR   Book II           The Mirror of Galadriel  Chapter 7 . The Mirror of Galadriel \n\n\n\nTh...  0.045263  0.061203  0.860048  0.078742  0.051823      0.331532
# 24   FOTR   Book II                Farewell to Lorien  Chapter 8 . Farewell to Lorien \n\n\n\nThat ni...  0.091091  0.050251  0.866813  0.082930  0.062147      0.321413
# 25   FOTR   Book II                   The Great River  Chapter 9 . The Great River \n\n\n\nFrodo was ... -0.020113  0.065061  0.890092  0.044852  0.018566      0.306630
# 26   FOTR   Book II    The Breaking of the Fellowship  Chapter 10. The Breaking of the Fellowship \n\... -0.025731  0.099378  0.834948  0.065674  0.003442      0.237485

# %%
chapters = [p1,p2,p3,p4,p5,b1_1,b1_2,b1_3,b1_4,b1_5,b1_6,b1_7,b1_8,b1_9,b1_10,b1_11,b1_12,b2_1,b2_2,b2_3,
         b2_4,b2_5,b2_6,b2_7,b2_8,b2_9,b2_10]

wordlength_list = list()

for chapter in chapters:
    count = len(chapter)
        
    wordlength_list.append(count)  

data7 = pd.DataFrame(wordlength_list)  
data7=data7.rename(columns={0: 'Total_words'})
data7
# Out:
#     Total_words
# 0         19430
# 1          3355
# 2          4696
# 3          8576
# 4          5279
# 5         55003
# 6         59702
# 7         51900
# 8         31132
# 9         27778
# 10        35355
# 11        30042
# 12        36168
# 13        33940
# 14        30897
# 15        51077
# 16        47165
# 17        48716
# 18        85863
# 19        57180
# 20        61928
# 21        29296
# 22        50428
# 23        36207
# 24        32963
# 25        38701
# 26        32624

# %%
FOTR_sentiments = pd.merge(FOTR_sentiments, data7, left_index=True, right_index=True)

FOTR_sentiments.to_csv(r'C:\Users\Nick\Desktop\GitProjects\NLP_projects\FOTR\FOTR_sentiments.csv')

FOTR_sentiments.head()
# Out:
#   Volume      Book                      Chapters                                               Text  Compound  Negative   Neutral  Positive  Polarity  Subjectivity  Total_words
# 0   FOTR  Prologue            Concerning Hobbits  1. Concerning Hobbits \n\n\n\nThis book is lar...  0.133970  0.043674  0.880891  0.075450  0.123098      0.453589        19430
# 1   FOTR  Prologue          Concerning Pipe-weed  2. Concerning Pipe-weed \n\n\n\nThere is anoth...  0.239865  0.014870  0.903565  0.081609  0.191711      0.472525         3355
# 2   FOTR  Prologue  Of the Ordering of the Shire  3. Of the Ordering of the Shire \n\n\n\nThe Sh...  0.042571  0.041147  0.903382  0.055471  0.097907      0.441715         4696
# 3   FOTR  Prologue    Of the Finding of the Ring  4. Of the Finding of the Ring \n\n\n\nAs is to...  0.075828  0.075471  0.841000  0.083485  0.041690      0.336673         8576
# 4   FOTR  Prologue     NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS \n\n\n\nAt the end o...  0.115635  0.025703  0.914108  0.060162  0.220372      0.394603         5279

# %%
def rating(FOTR_sentiments):
    if FOTR_sentiments['Compound'] > 0.05:
        return 'Positive'
    elif FOTR_sentiments['Compound'] < -0.05:
        return 'Negative'
    else:
        return 'Neutral'

FOTR_sentiments['Rating'] = FOTR_sentiments.apply(rating, axis=1)

FOTR_sentiments.to_csv(r'C:\Users\Nick\Desktop\GitProjects\NLP_projects\FOTR\FOTR_sentiments.csv')

FOTR_sentiments.head(27)
# Out:
#    Volume      Book                          Chapters                                               Text  Compound  Negative   Neutral  Positive  Polarity  Subjectivity  Total_words    Rating
# 0    FOTR  Prologue                Concerning Hobbits  1. Concerning Hobbits \n\n\n\nThis book is lar...  0.133970  0.043674  0.880891  0.075450  0.123098      0.453589        19430  Positive
# 1    FOTR  Prologue              Concerning Pipe-weed  2. Concerning Pipe-weed \n\n\n\nThere is anoth...  0.239865  0.014870  0.903565  0.081609  0.191711      0.472525         3355  Positive
# 2    FOTR  Prologue      Of the Ordering of the Shire  3. Of the Ordering of the Shire \n\n\n\nThe Sh...  0.042571  0.041147  0.903382  0.055471  0.097907      0.441715         4696   Neutral
# 3    FOTR  Prologue        Of the Finding of the Ring  4. Of the Finding of the Ring \n\n\n\nAs is to...  0.075828  0.075471  0.841000  0.083485  0.041690      0.336673         8576  Positive
# 4    FOTR  Prologue         NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS \n\n\n\nAt the end o...  0.115635  0.025703  0.914108  0.060162  0.220372      0.394603         5279  Positive
# 5    FOTR    Book I             A Long-expected Party  Chapter 1 . A Long-expected Party \n\nWhen Mr....  0.092960  0.050563  0.854325  0.095113  0.063388      0.297571        55003  Positive
# 6    FOTR    Book I            The Shadow of the Past  Chapter 2 . The Shadow of the Past \n\n\n\nThe...  0.023151  0.080364  0.835787  0.083856  0.046675      0.299241        59702   Neutral
# 7    FOTR    Book I                  Three is Company  Chapter 3 . Three is Company \n\n\n\n'You ough...  0.062997  0.039382  0.887917  0.072693  0.056428      0.285911        51900  Positive
# 8    FOTR    Book I          A Short Cut to Mushrooms  Chapter 4 . A Short Cut to Mushrooms \n\n\n\nI...  0.011641  0.054406  0.882502  0.063086  0.048184      0.262968        31132   Neutral
# 9    FOTR    Book I             A Conspiracy Unmasked  Chapter 5 . A Conspiracy Unmasked \n\n\n\n'Now...  0.083426  0.049687  0.853551  0.096768  0.046885      0.278871        27778  Positive
# 10   FOTR    Book I                    The Old Forest  Chapter 6. The Old Forest \n\n\n\nFrodo woke s...  0.050078  0.059573  0.859174  0.081251  0.011858      0.283457        35355  Positive
# 11   FOTR    Book I      In the House of Tom Bombadil  Chapter 7 . In the House of Tom Bombadil \n\n\...  0.109893  0.051551  0.848711  0.099737  0.078520      0.314967        30042  Positive
# 12   FOTR    Book I           Fog on the Barrow-Downs  Chapter 8 . Fog on the Barrow-Downs \n\n\n\nTh...  0.063105  0.056751  0.864729  0.078517  0.012824      0.315016        36168  Positive
# 13   FOTR    Book I  At the Sign of The Prancing Pony  Chapter 9 . At the Sign of \n\n\n\nThe Prancin...  0.063927  0.044007  0.889855  0.066140  0.055907      0.274922        33940  Positive
# 14   FOTR    Book I                           Strider  Chapter 10. Strider \n\n\n\nFrodo, Pippin, and...  0.031716  0.064495  0.854428  0.081069  0.018458      0.252212        30897   Neutral
# 15   FOTR    Book I               A Knife in the Dark  Chapter 11. A Knife in the Dark \n\n\n\nAs the... -0.017724  0.078997  0.860830  0.060170  0.012372      0.298401        51077   Neutral
# 16   FOTR    Book I                Flight to the Ford  Chapter 12 . Flight to the Ford \n\n\n\nWhen F... -0.039676  0.077316  0.866580  0.056111  0.007771      0.303397        47165   Neutral
# 17   FOTR   Book II                     Many Meetings  Chapter 1 . Many Meetings \n\nFrodo woke and f...  0.092482  0.047418  0.856683  0.095900  0.073006      0.287620        48716  Positive
# 18   FOTR   Book II             The Council of Elrond  Chapter 2 . The Council of Elrond \n\n\n\nNext...  0.007270  0.074671  0.853501  0.071823  0.040775      0.304679        85863   Neutral
# 19   FOTR   Book II               The Ring Goes South  Chapter 3 . The Ring Goes South \n\n\n\nLater ...  0.000085  0.064984  0.863647  0.068535  0.037318      0.313236        57180   Neutral
# 20   FOTR   Book II             A Journey in the Dark  Chapter 4 . A Journey in the Dark \n\n\n\nIt w... -0.018587  0.068742  0.871763  0.059500  0.010430      0.304156        61928   Neutral
# 21   FOTR   Book II          The Bridge of Khazad-dum  Chapter 5 . The Bridge of Khazad-dum \n\n\n\nT... -0.073328  0.097166  0.859562  0.043271  0.014297      0.247021        29296  Negative
# 22   FOTR   Book II                        Lothlorien  Chapter 6 . Lothlorien \n\n\n\n'Alas! I Fear w...  0.050481  0.052154  0.882938  0.064901  0.055373      0.290735        50428  Positive
# 23   FOTR   Book II           The Mirror of Galadriel  Chapter 7 . The Mirror of Galadriel \n\n\n\nTh...  0.045263  0.061203  0.860048  0.078742  0.051823      0.331532        36207   Neutral
# 24   FOTR   Book II                Farewell to Lorien  Chapter 8 . Farewell to Lorien \n\n\n\nThat ni...  0.091091  0.050251  0.866813  0.082930  0.062147      0.321413        32963  Positive
# 25   FOTR   Book II                   The Great River  Chapter 9 . The Great River \n\n\n\nFrodo was ... -0.020113  0.065061  0.890092  0.044852  0.018566      0.306630        38701   Neutral
# 26   FOTR   Book II    The Breaking of the Fellowship  Chapter 10. The Breaking of the Fellowship \n\... -0.025731  0.099378  0.834948  0.065674  0.003442      0.237485        32624   Neutral

# %%
import io, re, nltk
from pathlib import Path
from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk import FreqDist

chapters = [p1,p2,p3,p4,p5,b1_1,b1_2,b1_3,b1_4,b1_5,b1_6,b1_7,b1_8,b1_9,b1_10,b1_11,b1_12,b2_1,b2_2,b2_3,
         b2_4,b2_5,b2_6,b2_7,b2_8,b2_9,b2_10]

Noun_freq = list()

for chapter in chapters:
    chap = chapter
    data = chap.replace('\n', ' ')
    data_lower = data.lower()
    tokens = RegexpTokenizer(r'\w+').tokenize(data_lower)
    stop = set(stopwords.words('english'))
    words = [word for word in tokens if word not in stop]
    tagged = pos_tag(words)
    nouns = [word for word, pos in tagged if (pos == 'NN')]
    Noun1 = (0)
            
    Noun1 = FreqDist(nouns).most_common(10)
    
    Noun_freq.append(Noun1)
    
Noun_freq
# Out:
# [[('time', 12),
#   ('book', 9),
#   ('hobbit', 8),
#   ('world', 7),
#   ('shire', 6),
#   ('history', 5),
#   ('peace', 5),
#   ('folk', 5),
#   ('sea', 5),
#   ('age', 4)],
#  [('weed', 4),
#   ('pipe', 3),
#   ('shire', 3),
#   ('claim', 3),
#   ('leaf', 2),
#   ('art', 2),
#   ('family', 2),
#   ('home', 2),
#   ('toby', 2),
#   ('plant', 2)],
#  [('shire', 9),
#   ('time', 4),
#   ('family', 3),
#   ('number', 2),
#   ('course', 2),
#   ('norbury', 2),
#   ('thain', 2),
#   ('mayor', 2),
#   ('history', 1),
#   ('chapter', 1)],
#  [('bilbo', 15),
#   ('gollum', 12),
#   ('hobbit', 5),
#   ('way', 5),
#   ('island', 5),
#   ('game', 5),
#   ('hand', 4),
#   ('truth', 4),
#   ('gandalf', 3),
#   ('treasure', 3)],
#  [('book', 8),
#   ('shire', 7),
#   ('history', 6),
#   ('copy', 5),
#   ('age', 4),
#   ('interest', 3),
#   ('time', 3),
#   ('war', 3),
#   ('rivendell', 3),
#   ('peregrin', 3)],
#  [('bilbo', 55),
#   ('frodo', 27),
#   ('end', 24),
#   ('gandalf', 24),
#   ('time', 18),
#   ('party', 15),
#   ('hobbit', 15),
#   ('door', 15),
#   ('course', 14),
#   ('mr', 11)],
#  [('gandalf', 32),
#   ('frodo', 32),
#   ('bilbo', 29),
#   ('power', 23),
#   ('gollum', 23),
#   ('ring', 20),
#   ('shire', 19),
#   ('time', 18),
#   ('way', 16),
#   ('fire', 13)],
#  [('road', 43),
#   ('frodo', 37),
#   ('end', 24),
#   ('sam', 24),
#   ('gandalf', 20),
#   ('way', 20),
#   ('time', 19),
#   ('pippin', 19),
#   ('shire', 16),
#   ('water', 14)],
#  [('frodo', 25),
#   ('pippin', 25),
#   ('farmer', 15),
#   ('mr', 14),
#   ('sam', 12),
#   ('road', 12),
#   ('time', 12),
#   ('way', 11),
#   ('ferry', 11),
#   ('night', 8)],
#  [('merry', 25),
#   ('frodo', 22),
#   ('pippin', 12),
#   ('water', 11),
#   ('course', 9),
#   ('round', 8),
#   ('shire', 8),
#   ('way', 8),
#   ('time', 8),
#   ('day', 7)],
#  [('merry', 26),
#   ('path', 21),
#   ('way', 16),
#   ('water', 15),
#   ('side', 14),
#   ('sam', 11),
#   ('ground', 11),
#   ('tree', 11),
#   ('river', 11),
#   ('tom', 11)],
#  [('tom', 35),
#   ('water', 18),
#   ('house', 14),
#   ('goldberry', 12),
#   ('frodo', 12),
#   ('morning', 12),
#   ('room', 11),
#   ('master', 10),
#   ('bombadil', 9),
#   ('door', 8)],
#  [('tom', 25),
#   ('hill', 16),
#   ('sun', 15),
#   ('frodo', 14),
#   ('merry', 13),
#   ('road', 12),
#   ('barrow', 11),
#   ('grass', 11),
#   ('line', 11),
#   ('time', 11)],
#  [('frodo', 22),
#   ('folk', 20),
#   ('butterbur', 17),
#   ('man', 15),
#   ('bree', 13),
#   ('mr', 13),
#   ('road', 11),
#   ('room', 11),
#   ('moment', 10),
#   ('shire', 9)],
#  [('strider', 39),
#   ('frodo', 17),
#   ('butterbur', 16),
#   ('name', 14),
#   ('mr', 14),
#   ('gandalf', 14),
#   ('letter', 13),
#   ('sam', 12),
#   ('road', 12),
#   ('night', 11)],
#  [('strider', 43),
#   ('night', 22),
#   ('road', 22),
#   ('hill', 19),
#   ('day', 16),
#   ('fire', 16),
#   ('time', 16),
#   ('way', 16),
#   ('frodo', 15),
#   ('house', 13)],
#  [('road', 38),
#   ('frodo', 34),
#   ('strider', 34),
#   ('horse', 20),
#   ('way', 19),
#   ('troll', 15),
#   ('glorfindel', 15),
#   ('water', 14),
#   ('night', 14),
#   ('ford', 13)],
#  [('frodo', 42),
#   ('elrond', 25),
#   ('gandalf', 23),
#   ('bilbo', 19),
#   ('time', 15),
#   ('moment', 12),
#   ('face', 12),
#   ('house', 11),
#   ('music', 11),
#   ('rivendell', 10)],
#  [('elrond', 37),
#   ('time', 32),
#   ('power', 31),
#   ('gandalf', 29),
#   ('sauron', 23),
#   ('day', 22),
#   ('world', 22),
#   ('ring', 21),
#   ('saruman', 20),
#   ('hand', 18)],
#  [('gandalf', 35),
#   ('frodo', 24),
#   ('company', 23),
#   ('way', 21),
#   ('night', 17),
#   ('fire', 17),
#   ('wind', 16),
#   ('elrond', 15),
#   ('boromir', 14),
#   ('pippin', 13)],
#  [('gandalf', 48),
#   ('way', 28),
#   ('water', 27),
#   ('road', 22),
#   ('night', 19),
#   ('company', 19),
#   ('gimli', 19),
#   ('stone', 19),
#   ('nothing', 18),
#   ('sam', 14)],
#  [('doom', 29),
#   ('gandalf', 27),
#   ('door', 20),
#   ('bridge', 15),
#   ('fire', 14),
#   ('way', 12),
#   ('hall', 12),
#   ('chamber', 11),
#   ('side', 11),
#   ('something', 11)],
#  [('frodo', 28),
#   ('water', 20),
#   ('road', 17),
#   ('haldir', 17),
#   ('company', 16),
#   ('gimli', 16),
#   ('land', 16),
#   ('wood', 13),
#   ('world', 13),
#   ('tree', 13)],
#  [('galadriel', 17),
#   ('frodo', 14),
#   ('lady', 12),
#   ('gandalf', 12),
#   ('mirror', 11),
#   ('sam', 11),
#   ('lord', 10),
#   ('road', 10),
#   ('land', 9),
#   ('cannot', 9)],
#  [('river', 18),
#   ('company', 14),
#   ('night', 11),
#   ('water', 11),
#   ('lady', 10),
#   ('land', 9),
#   ('galadriel', 9),
#   ('way', 9),
#   ('boromir', 9),
#   ('tongue', 9)],
#  [('night', 35),
#   ('river', 25),
#   ('water', 23),
#   ('day', 22),
#   ('frodo', 17),
#   ('way', 16),
#   ('bank', 15),
#   ('boat', 14),
#   ('time', 13),
#   ('company', 11)],
#  [('frodo', 32),
#   ('sam', 21),
#   ('boromir', 19),
#   ('way', 13),
#   ('river', 10),
#   ('heart', 9),
#   ('boat', 9),
#   ('water', 8),
#   ('hand', 8),
#   ('stone', 8)]]

# %%
# The Lexical Diversity represents the ratio of unique words used to the total number of words in the story.

chapters = [p1,p2,p3,p4,p5,b1_1,b1_2,b1_3,b1_4,b1_5,b1_6,b1_7,b1_8,b1_9,b1_10,b1_11,b1_12,b2_1,b2_2,b2_3,
         b2_4,b2_5,b2_6,b2_7,b2_8,b2_9,b2_10]

def lexical_density(text):
    return len(set(text)) / len(text)

Lexical_density = list()

for chapter in chapters:
    chap = chapter
    data = chap.replace('\n', ' ')
    data_lower = data.lower()
    tokens = RegexpTokenizer(r'\w+').tokenize(data_lower)
    LexDen = (0)
            
    LexDen = lexical_density(tokens)

    Lexical_density.append(LexDen)  

LexDen = pd.DataFrame(Lexical_density) 
LexDen=LexDen.rename(columns={0: 'Lex_density'})
LexDen
# Out:
#     Lex_density
# 0      0.290210
# 1      0.466338
# 2      0.442961
# 3      0.335784
# 4      0.377682
# 5      0.197489
# 6      0.160103
# 7      0.174535
# 8      0.203364
# 9      0.221496
# 10     0.215347
# 11     0.230714
# 12     0.210746
# 13     0.222187
# 14     0.190234
# 15     0.196132
# 16     0.186933
# 17     0.192164
# 18     0.133704
# 19     0.180420
# 20     0.175262
# 21     0.220451
# 22     0.173443
# 23     0.195362
# 24     0.218679
# 25     0.213239
# 26     0.206858

# %%
# The Lexical Diversity represents the ratio of unique words used to the total number of words in the story.

chapters = [p1,p2,p3,p4,p5,b1_1,b1_2,b1_3,b1_4,b1_5,b1_6,b1_7,b1_8,b1_9,b1_10,b1_11,b1_12,b2_1,b2_2,b2_3,
         b2_4,b2_5,b2_6,b2_7,b2_8,b2_9,b2_10]

def lexical_density(text):
    return len(set(text)) / len(text)

Lexical_density_norm = list()

for chapter in chapters:
    chap = chapter
    data = chap.replace('\n', ' ')
    data_lower = data.lower()
    tokens = RegexpTokenizer(r'\w+').tokenize(data_lower)
    tokens = tokens[0:27778]
    LexDen1 = (0)
            
    LexDen1 = lexical_density(tokens)

    Lexical_density_norm.append(LexDen1)  

LexDen_norm = pd.DataFrame(Lexical_density_norm) 
LexDen_norm=LexDen_norm.rename(columns={0: 'Lex_density_norm'})
LexDen_norm
# Out:
#     Lex_density_norm
# 0           0.290210
# 1           0.466338
# 2           0.442961
# 3           0.335784
# 4           0.377682
# 5           0.197489
# 6           0.160103
# 7           0.174535
# 8           0.203364
# 9           0.221496
# 10          0.215347
# 11          0.230714
# 12          0.210746
# 13          0.222187
# 14          0.190234
# 15          0.196132
# 16          0.186933
# 17          0.192164
# 18          0.133704
# 19          0.180420
# 20          0.175262
# 21          0.220451
# 22          0.173443
# 23          0.195362
# 24          0.218679
# 25          0.213239
# 26          0.206858

# %%
FOTR_sentiments = pd.merge(FOTR_sentiments, LexDen, left_index=True, right_index=True)

FOTR_sentiments = FOTR_sentiments[['Volume','Book','Chapters','Text','Total_words','Lex_density','Negative',
                                                  'Neutral','Positive','Compound','Rating','Polarity','Subjectivity']]

FOTR_sentiments.to_csv(r'C:\Users\Nick\Desktop\GitProjects\NLP_projects\FOTR\FOTR_sentiments.csv')

FOTR_sentiments.head()
# Out:
#   Volume      Book                      Chapters                                               Text  Total_words  Lex_density  Negative   Neutral  Positive  Compound    Rating  Polarity  Subjectivity
# 0   FOTR  Prologue            Concerning Hobbits  1. Concerning Hobbits \n\n\n\nThis book is lar...        19430     0.290210  0.043674  0.880891  0.075450  0.133970  Positive  0.123098      0.453589
# 1   FOTR  Prologue          Concerning Pipe-weed  2. Concerning Pipe-weed \n\n\n\nThere is anoth...         3355     0.466338  0.014870  0.903565  0.081609  0.239865  Positive  0.191711      0.472525
# 2   FOTR  Prologue  Of the Ordering of the Shire  3. Of the Ordering of the Shire \n\n\n\nThe Sh...         4696     0.442961  0.041147  0.903382  0.055471  0.042571   Neutral  0.097907      0.441715
# 3   FOTR  Prologue    Of the Finding of the Ring  4. Of the Finding of the Ring \n\n\n\nAs is to...         8576     0.335784  0.075471  0.841000  0.083485  0.075828  Positive  0.041690      0.336673
# 4   FOTR  Prologue     NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS \n\n\n\nAt the end o...         5279     0.377682  0.025703  0.914108  0.060162  0.115635  Positive  0.220372      0.394603

# %%
FOTR_sentiments = pd.merge(FOTR_sentiments, LexDen_norm, left_index=True, right_index=True)

FOTR_sentiments = FOTR_sentiments[['Volume','Book','Chapters','Text','Total_words','Lex_density','Lex_density_norm','Negative',
                                                  'Neutral','Positive','Compound','Rating','Polarity','Subjectivity']]

FOTR_sentiments.to_csv(r'C:\Users\Nick\Desktop\GitProjects\NLP_projects\FOTR\FOTR_sentiments.csv')

FOTR_sentiments.head()
# Out:
#   Volume      Book                      Chapters                                               Text  Total_words  Lex_density  Lex_density_norm  Negative   Neutral  Positive  Compound    Rating  Polarity  Subjectivity
# 0   FOTR  Prologue            Concerning Hobbits  1. Concerning Hobbits \n\n\n\nThis book is lar...        19430     0.290210          0.290210  0.043674  0.880891  0.075450  0.133970  Positive  0.123098      0.453589
# 1   FOTR  Prologue          Concerning Pipe-weed  2. Concerning Pipe-weed \n\n\n\nThere is anoth...         3355     0.466338          0.466338  0.014870  0.903565  0.081609  0.239865  Positive  0.191711      0.472525
# 2   FOTR  Prologue  Of the Ordering of the Shire  3. Of the Ordering of the Shire \n\n\n\nThe Sh...         4696     0.442961          0.442961  0.041147  0.903382  0.055471  0.042571   Neutral  0.097907      0.441715
# 3   FOTR  Prologue    Of the Finding of the Ring  4. Of the Finding of the Ring \n\n\n\nAs is to...         8576     0.335784          0.335784  0.075471  0.841000  0.083485  0.075828  Positive  0.041690      0.336673
# 4   FOTR  Prologue     NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS \n\n\n\nAt the end o...         5279     0.377682          0.377682  0.025703  0.914108  0.060162  0.115635  Positive  0.220372      0.394603

# %%
FOTR_sentiments = FOTR_sentiments.replace('\n',' ', regex=True) 
FOTR_sentiments.head()
# Out:
#   Volume      Book                      Chapters                                               Text  Total_words  Lex_density  Lex_density_norm  Negative   Neutral  Positive  Compound    Rating  Polarity  Subjectivity
# 0   FOTR  Prologue            Concerning Hobbits  1. Concerning Hobbits     This book is largely...        19430     0.290210          0.290210  0.043674  0.880891  0.075450  0.133970  Positive  0.123098      0.453589
# 1   FOTR  Prologue          Concerning Pipe-weed  2. Concerning Pipe-weed     There is another a...         3355     0.466338          0.466338  0.014870  0.903565  0.081609  0.239865  Positive  0.191711      0.472525
# 2   FOTR  Prologue  Of the Ordering of the Shire  3. Of the Ordering of the Shire     The Shire ...         4696     0.442961          0.442961  0.041147  0.903382  0.055471  0.042571   Neutral  0.097907      0.441715
# 3   FOTR  Prologue    Of the Finding of the Ring  4. Of the Finding of the Ring     As is told i...         8576     0.335784          0.335784  0.075471  0.841000  0.083485  0.075828  Positive  0.041690      0.336673
# 4   FOTR  Prologue     NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS     At the end of th...         5279     0.377682          0.377682  0.025703  0.914108  0.060162  0.115635  Positive  0.220372      0.394603

# %%
import pandas as pd
from nltk import word_tokenize
from nltk.stem.snowball import SnowballStemmer
from tqdm import tqdm_notebook as tqdm
from tqdm import trange


def text_emotion(df, column):
    '''
    INPUT: DataFrame, string
    OUTPUT: the original DataFrame with ten new columns for each emotion
    '''

    new_df = df.copy()

    xlsx = pd.read_excel(r'C:\Users\Nick\Desktop\GitProjects\NLP_projects\The_Silmarillion\NRC-Sentiment-Emotion-Lexicons\NRC-Sentiment-Emotion-Lexicons\NRC-Emotion-Lexicon-v0.92\NRC-Emotion-Lexicon-v0.92-In105Languages-Nov2017Translations.xlsx')
    emolex_df = xlsx[['word', 'Positive_NRC','Negative_NRC','Anger', 'Anticipation', 'Disgust', 'Fear','Joy',
                      'Sadness', 'Surprise', 'Trust']]
    emotions = emolex_df.columns.drop('word')
    emo_df = pd.DataFrame(0, index=df.index, columns=emotions)

    stemmer = SnowballStemmer("english")

    
    with tqdm(total=len(list(new_df.iterrows()))) as pbar:
        for i, row in new_df.iterrows():
            pbar.update(1)
            document = word_tokenize(new_df.loc[i][column])
            for word in document:
                word = stemmer.stem(word.lower())
                emo_score = emolex_df[emolex_df.word == word]
                if not emo_score.empty:
                    for emotion in list(emotions):
                        emo_df.at[i, emotion] += emo_score[emotion]

    new_df = pd.concat([new_df, emo_df], axis=1)

    return new_df

# %%
FOTR_sentiments_final = text_emotion(FOTR_sentiments, 'Text')
# Out:
# HBox(children=(IntProgress(value=0, max=27), HTML(value='')))

# %%
FOTR_sentiments_final.head()
# Out:
#   Volume      Book                      Chapters                                               Text  Total_words  Lex_density  Lex_density_norm  Negative   Neutral  Positive  Compound    Rating  Polarity  Subjectivity  Positive_NRC  Negative_NRC  Anger  Anticipation  Disgust  Fear  Joy  Sadness  Surprise  Trust
# 0   FOTR  Prologue            Concerning Hobbits  1. Concerning Hobbits     This book is largely...        19430     0.290210          0.290210  0.043674  0.880891  0.075450  0.133970  Positive  0.123098      0.453589           156            63     27            77       10    40   49       39        23     75
# 1   FOTR  Prologue          Concerning Pipe-weed  2. Concerning Pipe-weed     There is another a...         3355     0.466338          0.466338  0.014870  0.903565  0.081609  0.239865  Positive  0.191711      0.472525            28            10      1            20        1     5   16        8        12     15
# 2   FOTR  Prologue  Of the Ordering of the Shire  3. Of the Ordering of the Shire     The Shire ...         4696     0.442961          0.442961  0.041147  0.903382  0.055471  0.042571   Neutral  0.097907      0.441715            39            17      4            19        2    10   16        2         3     29
# 3   FOTR  Prologue    Of the Finding of the Ring  4. Of the Finding of the Ring     As is told i...         8576     0.335784          0.335784  0.075471  0.841000  0.083485  0.075828  Positive  0.041690      0.336673            79            50     22            54       14    32   37       31        41     51
# 4   FOTR  Prologue     NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS     At the end of th...         5279     0.377682          0.377682  0.025703  0.914108  0.060162  0.115635  Positive  0.220372      0.394603            36            11      2             9        2     5    6        4         3     19

# %%
FOTR_sentiments_final['word_count'] = FOTR_sentiments_final['Text'].apply(tokenize.word_tokenize).apply(len)
FOTR_sentiments_final.head()
# Out:
#   Volume      Book                      Chapters                                               Text  Total_words  Lex_density  Lex_density_norm  Negative   Neutral  Positive  Compound    Rating  Polarity  Subjectivity  Positive_NRC  Negative_NRC  Anger  Anticipation  Disgust  Fear  Joy  Sadness  Surprise  Trust  word_count
# 0   FOTR  Prologue            Concerning Hobbits  1. Concerning Hobbits     This book is largely...        19430     0.290210          0.290210  0.043674  0.880891  0.075450  0.133970  Positive  0.123098      0.453589           156            63     27            77       10    40   49       39        23     75        3839
# 1   FOTR  Prologue          Concerning Pipe-weed  2. Concerning Pipe-weed     There is another a...         3355     0.466338          0.466338  0.014870  0.903565  0.081609  0.239865  Positive  0.191711      0.472525            28            10      1            20        1     5   16        8        12     15         680
# 2   FOTR  Prologue  Of the Ordering of the Shire  3. Of the Ordering of the Shire     The Shire ...         4696     0.442961          0.442961  0.041147  0.903382  0.055471  0.042571   Neutral  0.097907      0.441715            39            17      4            19        2    10   16        2         3     29         947
# 3   FOTR  Prologue    Of the Finding of the Ring  4. Of the Finding of the Ring     As is told i...         8576     0.335784          0.335784  0.075471  0.841000  0.083485  0.075828  Positive  0.041690      0.336673            79            50     22            54       14    32   37       31        41     51        1854
# 4   FOTR  Prologue     NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS     At the end of th...         5279     0.377682          0.377682  0.025703  0.914108  0.060162  0.115635  Positive  0.220372      0.394603            36            11      2             9        2     5    6        4         3     19        1029

# %%
FOTR_sentiments_final.dtypes
# Out:
# Volume               object
# Book                 object
# Chapters             object
# Text                 object
# Total_words           int64
# Lex_density         float64
# Lex_density_norm    float64
# Negative            float64
# Neutral             float64
# Positive            float64
# Compound            float64
# Rating               object
# Polarity            float64
# Subjectivity        float64
# Positive_NRC          int64
# Negative_NRC          int64
# Anger                 int64
# Anticipation          int64
# Disgust               int64
# Fear                  int64
# Joy                   int64
# Sadness               int64
# Surprise              int64
# Trust                 int64
# word_count            int64
# dtype: object

# %%
emotions = ['Positive_NRC','Negative_NRC','Anger','Anticipation','Disgust','Fear','Joy','Sadness','Surprise',
                 'Trust']

# %%
for emotion in emotions:
    FOTR_sentiments_final[emotion]=FOTR_sentiments_final[emotion]/FOTR_sentiments_final['word_count']

FOTR_sentiments_final.head()
# Out:
#   Volume      Book                      Chapters                                               Text  Total_words  Lex_density  Lex_density_norm  Negative   Neutral  Positive  Compound    Rating  Polarity  Subjectivity  Positive_NRC  Negative_NRC     Anger  Anticipation   Disgust      Fear       Joy   Sadness  Surprise     Trust  word_count
# 0   FOTR  Prologue            Concerning Hobbits  1. Concerning Hobbits     This book is largely...        19430     0.290210          0.290210  0.043674  0.880891  0.075450  0.133970  Positive  0.123098      0.453589      0.040636      0.016411  0.007033      0.020057  0.002605  0.010419  0.012764  0.010159  0.005991  0.019536        3839
# 1   FOTR  Prologue          Concerning Pipe-weed  2. Concerning Pipe-weed     There is another a...         3355     0.466338          0.466338  0.014870  0.903565  0.081609  0.239865  Positive  0.191711      0.472525      0.041176      0.014706  0.001471      0.029412  0.001471  0.007353  0.023529  0.011765  0.017647  0.022059         680
# 2   FOTR  Prologue  Of the Ordering of the Shire  3. Of the Ordering of the Shire     The Shire ...         4696     0.442961          0.442961  0.041147  0.903382  0.055471  0.042571   Neutral  0.097907      0.441715      0.041183      0.017951  0.004224      0.020063  0.002112  0.010560  0.016895  0.002112  0.003168  0.030623         947
# 3   FOTR  Prologue    Of the Finding of the Ring  4. Of the Finding of the Ring     As is told i...         8576     0.335784          0.335784  0.075471  0.841000  0.083485  0.075828  Positive  0.041690      0.336673      0.042611      0.026969  0.011866      0.029126  0.007551  0.017260  0.019957  0.016721  0.022114  0.027508        1854
# 4   FOTR  Prologue     NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS     At the end of th...         5279     0.377682          0.377682  0.025703  0.914108  0.060162  0.115635  Positive  0.220372      0.394603      0.034985      0.010690  0.001944      0.008746  0.001944  0.004859  0.005831  0.003887  0.002915  0.018465        1029

# %%
def ratings(FOTR_sentiments_final):
    if FOTR_sentiments_final['Compound'] > 0.05:
        return 1
    elif FOTR_sentiments_final['Compound'] < -0.05:
        return -1
    else:
        return 0

FOTR_sentiments_final['Rating_num'] = FOTR_sentiments_final.apply(ratings, axis=1)

FOTR_sentiments_final.to_csv(r'C:\Users\Nick\Desktop\GitProjects\NLP_projects\FOTR\FOTR_sentiments.csv')

FOTR_sentiments_final.head(10)
# Out:
#   Volume      Book                      Chapters                                               Text  Total_words  Lex_density  Lex_density_norm  Negative   Neutral  Positive  Compound    Rating  Polarity  Subjectivity  Positive_NRC  Negative_NRC     Anger  Anticipation   Disgust      Fear       Joy   Sadness  Surprise     Trust  word_count  Rating_num
# 0   FOTR  Prologue            Concerning Hobbits  1. Concerning Hobbits     This book is largely...        19430     0.290210          0.290210  0.043674  0.880891  0.075450  0.133970  Positive  0.123098      0.453589      0.040636      0.016411  0.007033      0.020057  0.002605  0.010419  0.012764  0.010159  0.005991  0.019536        3839           1
# 1   FOTR  Prologue          Concerning Pipe-weed  2. Concerning Pipe-weed     There is another a...         3355     0.466338          0.466338  0.014870  0.903565  0.081609  0.239865  Positive  0.191711      0.472525      0.041176      0.014706  0.001471      0.029412  0.001471  0.007353  0.023529  0.011765  0.017647  0.022059         680           1
# 2   FOTR  Prologue  Of the Ordering of the Shire  3. Of the Ordering of the Shire     The Shire ...         4696     0.442961          0.442961  0.041147  0.903382  0.055471  0.042571   Neutral  0.097907      0.441715      0.041183      0.017951  0.004224      0.020063  0.002112  0.010560  0.016895  0.002112  0.003168  0.030623         947           0
# 3   FOTR  Prologue    Of the Finding of the Ring  4. Of the Finding of the Ring     As is told i...         8576     0.335784          0.335784  0.075471  0.841000  0.083485  0.075828  Positive  0.041690      0.336673      0.042611      0.026969  0.011866      0.029126  0.007551  0.017260  0.019957  0.016721  0.022114  0.027508        1854           1
# 4   FOTR  Prologue     NOTE ON THE SHIRE RECORDS  NOTE ON THE SHIRE RECORDS     At the end of th...         5279     0.377682          0.377682  0.025703  0.914108  0.060162  0.115635  Positive  0.220372      0.394603      0.034985      0.010690  0.001944      0.008746  0.001944  0.004859  0.005831  0.003887  0.002915  0.018465        1029           1
# 5   FOTR    Book I         A Long-expected Party  Chapter 1 . A Long-expected Party   When Mr. B...        55003     0.197489          0.197489  0.050563  0.854325  0.095113  0.092960  Positive  0.063388      0.297571      0.035862      0.016163  0.005893      0.022898  0.004377  0.007240  0.020540  0.006735  0.015742  0.020877       11879           1
# 6   FOTR    Book I        The Shadow of the Past  Chapter 2 . The Shadow of the Past     The tal...        59702     0.160103          0.160103  0.080364  0.835787  0.083856  0.023151   Neutral  0.046675      0.299241      0.034140      0.025718  0.009926      0.024289  0.006693  0.016769  0.016168  0.014814  0.013160  0.022635       13298           0
# 7   FOTR    Book I              Three is Company  Chapter 3 . Three is Company     'You ought to...        51900     0.174535          0.174535  0.039382  0.887917  0.072693  0.062997  Positive  0.056428      0.285911      0.035402      0.020804  0.008129      0.021154  0.005857  0.009703  0.014948  0.010839  0.012325  0.021416       11440           1
# 8   FOTR    Book I      A Short Cut to Mushrooms  Chapter 4 . A Short Cut to Mushrooms     In th...        31132     0.203364          0.203364  0.054406  0.882502  0.063086  0.011641   Neutral  0.048184      0.262968      0.031294      0.022760  0.008677      0.016643  0.007966  0.010526  0.014651  0.008962  0.012233  0.019630        7030           0
# 9   FOTR    Book I         A Conspiracy Unmasked  Chapter 5 . A Conspiracy Unmasked     'Now we ...        27778     0.221496          0.221496  0.049687  0.853551  0.096768  0.083426  Positive  0.046885      0.278871      0.032920      0.019068  0.005541      0.021675  0.003911  0.008963  0.014016  0.009615  0.014016  0.019883        6136           1
